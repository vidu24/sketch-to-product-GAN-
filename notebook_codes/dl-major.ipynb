# %%
import os
import torch
import numpy as np
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
import matplotlib.pyplot as plt
import random

# %%
class StackedGANData(Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        # Filtering to ensure we only grab image files
        self.list_files = [f for f in os.listdir(self.root_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]

    def __len__(self):
        return len(self.list_files)

    def __getitem__(self, index):
        img_file = self.list_files[index]
        img_path = os.path.join(self.root_dir, img_file)
        
        # Load image and convert to RGB
        image = Image.open(img_path).convert("RGB")
        width, height = image.size # Usually 512x256
        
        # Split the image
        # Edges2Shoes: Sketch on Left, Real on Right
        sketch = image.crop((0, 0, width//2, height))
        real = image.crop((width//2, 0, width, height))

        # --- Synchronized Augmentation ---
        # Pix2Pix works best with 'Random Jitter' (Resize to 286, then Random Crop to 256)
        # This prevents the model from "memorizing" exact pixel locations.
        
        # Resize
        resize = transforms.Resize(size=(286, 286))
        sketch = resize(sketch)
        real = resize(real)

        # Random Crop
        i, j, h, w = transforms.RandomCrop.get_params(sketch, output_size=(256, 256))
        sketch = TF.crop(sketch, i, j, h, w)
        real = TF.crop(real, i, j, h, w)

        # Random Horizontal Flip
        if random.random() > 0.5:
            sketch = TF.hflip(sketch)
            real = TF.hflip(real)

        # Transform to Tensor and Normalize to [-1, 1]
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])

        return transform(sketch), transform(real)

# %%
# --- Initialization ---
# Verify this path in your Kaggle 'Input' sidebar
TRAIN_DIR = "/kaggle/input/datasets/balraj98/edges2shoes-dataset/train" 

if not os.path.exists(TRAIN_DIR):
    print(f"⚠️ Warning: {TRAIN_DIR} not found. Check your dataset path!")

dataset = StackedGANData(root_dir=TRAIN_DIR)
train_loader = DataLoader(dataset, batch_size=8, shuffle=True, num_workers=2, pin_memory=True)

# --- Verification Step ---
def show_batch(loader):
    sketches, reals = next(iter(loader))
    plt.figure(figsize=(12, 6))
    for i in range(4):
        # Sketch
        plt.subplot(2, 4, i+1)
        plt.imshow(sketches[i].permute(1, 2, 0) * 0.5 + 0.5)
        plt.axis('off')
        if i == 0: plt.title("Augmented Sketch")
        
        # Real
        plt.subplot(2, 4, i+5)
        plt.imshow(reals[i].permute(1, 2, 0) * 0.5 + 0.5)
        plt.axis('off')
        if i == 0: plt.title("Augmented Real")
    plt.tight_layout()
    plt.show()

show_batch(train_loader)

# %%
import torch
import torch.nn as nn

class UNetBlock(nn.Module):
    def __init__(self, in_channels, out_channels, down=True, use_dropout=False):
        super(UNetBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 4, 2, 1, bias=False, padding_mode="reflect")
            if down
            else nn.ConvTranspose2d(in_channels, out_channels, 4, 2, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True) if not down else nn.LeakyReLU(0.2, inplace=True),
        )
        self.use_dropout = use_dropout
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.conv(x)
        return self.dropout(x) if self.use_dropout else x

# %%
class Stage1Generator(nn.Module):
    def __init__(self, in_channels=3, features=64):
        super().__init__()
        # Encoder: 256 -> 128 -> 64 -> 32 -> 16 -> 8 -> 4 -> 2
        self.initial_down = nn.Sequential(
            nn.Conv2d(in_channels, features, 4, 2, 1, padding_mode="reflect"),
            nn.LeakyReLU(0.2),
        ) 
        
        self.down1 = UNetBlock(features, features * 2)      
        self.down2 = UNetBlock(features * 2, features * 4) 
        self.down3 = UNetBlock(features * 4, features * 8) 
        self.down4 = UNetBlock(features * 8, features * 8) 
        self.down5 = UNetBlock(features * 8, features * 8) 
        self.down6 = UNetBlock(features * 8, features * 8) 
        
        # Bottleneck: 2 -> 1
        self.bottleneck = nn.Sequential(
            nn.Conv2d(features * 8, features * 8, 4, 2, 1), 
            nn.ReLU(inplace=True)
        )

        # Decoder with Skip Connections: 1 -> 2 -> 4 -> 8 -> 16 -> 32 -> 64 -> 128
        self.up1 = UNetBlock(features * 8, features * 8, down=False, use_dropout=True)
        self.up2 = UNetBlock(features * 8 * 2, features * 8, down=False, use_dropout=True)
        self.up3 = UNetBlock(features * 8 * 2, features * 8, down=False, use_dropout=True)
        self.up4 = UNetBlock(features * 8 * 2, features * 8, down=False)
        self.up5 = UNetBlock(features * 8 * 2, features * 4, down=False)
        self.up6 = UNetBlock(features * 4 * 2, features * 2, down=False)
        self.up7 = UNetBlock(features * 2 * 2, features, down=False)
        
        # Final Layer: 128 -> 256
        self.final_up = nn.Sequential(
            nn.ConvTranspose2d(features * 2, in_channels, kernel_size=4, stride=2, padding=1),
            nn.Tanh(), 
        )

    def forward(self, x):
        # Encoder
        d1 = self.initial_down(x)
        d2 = self.down1(d1)
        d3 = self.down2(d2)
        d4 = self.down3(d3)
        d5 = self.down4(d4)
        d6 = self.down5(d5)
        d7 = self.down6(d6)
        bn = self.bottleneck(d7)

        # Decoder with Skip Connections (Concatenating encoder features)
        u1 = self.up1(bn)
        u2 = self.up2(torch.cat([u1, d7], 1))
        u3 = self.up3(torch.cat([u2, d6], 1))
        u4 = self.up4(torch.cat([u3, d5], 1))
        u5 = self.up5(torch.cat([u4, d4], 1))
        u6 = self.up6(torch.cat([u5, d3], 1))
        u7 = self.up7(torch.cat([u6, d2], 1))
        
        # Final cat with d1 before the last upsample
        return self.final_up(torch.cat([u7, d1], 1))

# %%
# Quick Validation
device = "cuda" if torch.cuda.is_available() else "cpu"
model_gen1 = Stage1Generator().to(device)
gen1 = model_gen1
print("Stage 1 Generator initialized with Skip Connections.")
# Out:
# Stage 1 Generator initialized with Skip Connections.

# %%
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(channels, channels, kernel_size=3, padding=1, bias=False, padding_mode="reflect"),
            nn.BatchNorm2d(channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(channels, channels, kernel_size=3, padding=1, bias=False, padding_mode="reflect"),
            nn.BatchNorm2d(channels)
        )

    def forward(self, x):
        # The residual connection is key to preventing the "green noise"
        return x + self.block(x)

# %%
class Stage2Refiner(nn.Module):
    def __init__(self, in_channels=3, features=64, num_residuals=9): # Increased to 9 for better texture
        super().__init__()
        
        # Using a 7x7 kernel for the initial layer helps the model see a wider 
        # area of the coarse image to fix local artifacts.
        self.initial = nn.Sequential(
            nn.Conv2d(in_channels, features, kernel_size=7, stride=1, padding=3, padding_mode="reflect"),
            nn.BatchNorm2d(features),
            nn.ReLU(inplace=True)
        )
        
        # Residual blocks do the heavy lifting of sharpening the image
        self.res_blocks = nn.Sequential(
            *[ResidualBlock(features) for _ in range(num_residuals)]
        )
        
        # Final layer to bring it back to 3 channels
        self.final = nn.Sequential(
            nn.Conv2d(features, in_channels, kernel_size=7, stride=1, padding=3, padding_mode="reflect"),
            nn.Tanh() 
        )

    def forward(self, x):
        out = self.initial(x)
        out = self.res_blocks(out)
        return self.final(out)

# %%
# --- Validation ---
model_gen2 = Stage2Refiner().to(device)
gen2=model_gen2
print("Stage 2 Refiner initialized with Residual Blocks.")
# Out:
# Stage 2 Refiner initialized with Residual Blocks.

# %%
class DiscBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride):
        super(DiscBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 4, stride, 1, bias=False, padding_mode="reflect"),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2, inplace=True),
        )

    def forward(self, x):
        return self.conv(x)

class PatchGANDiscriminator(nn.Module):
    def __init__(self, in_channels=3, features=[64, 128, 256, 512]):
        super().__init__()
        # Initial layer: No BatchNorm as per original Pix2Pix paper
        self.initial = nn.Sequential(
            nn.Conv2d(in_channels * 2, features[0], kernel_size=4, stride=2, padding=1, padding_mode="reflect"),
            nn.LeakyReLU(0.2, inplace=True),
        )

        layers = []
        in_chs = features[0]
        # Intermediate layers
        for feature in features[1:]:
            # The original architecture uses stride 2 until the last feature map
            # then uses stride 1 to keep the final grid size useful.
            stride = 1 if feature == features[-1] else 2
            layers.append(DiscBlock(in_chs, feature, stride=stride))
            in_chs = feature

        # Final prediction layer: Produces the 30x30 (approx) grid of real/fake scores
        layers.append(
            nn.Conv2d(in_chs, 1, kernel_size=4, stride=1, padding=1, padding_mode="reflect"),
        )

        self.model = nn.Sequential(*layers)

    def forward(self, sketch, product):
        # Concatenate along the channel dimension (3+3=6)
        x = torch.cat([sketch, product], dim=1)
        x = self.initial(x)
        return self.model(x)

# %%
# --- Validation ---
model_disc = PatchGANDiscriminator().to(device)
disc = model_disc
print(f"Discriminator ready. Input: 6 channels, Output: Patch grid.")
# Out:
# Discriminator ready. Input: 6 channels, Output: Patch grid.

# %%
from torchvision import models

class VGGPerceptualLoss(nn.Module):
    def __init__(self):
        super(VGGPerceptualLoss, self).__init__()
        # Using VGG19 features pre-trained on ImageNet
        vgg = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1).features
        self.slice1 = nn.Sequential(*vgg[:4])   # Captures basic edges
        self.slice2 = nn.Sequential(*vgg[4:9])  # Captures textures
        self.slice3 = nn.Sequential(*vgg[9:18]) # Captures structural parts
        
        # Freeze weights so we don't train VGG itself
        for param in self.parameters():
            param.requires_grad = False
            
    def forward(self, x, y):
        # x and y are in range [-1, 1]. VGG likes [0, 1] with ImageNet normalization.
        # We'll do a simple shift here to keep it efficient.
        x = (x + 1) / 2
        y = (y + 1) / 2
        
        h1_x, h1_y = self.slice1(x), self.slice1(y)
        h2_x, h2_y = self.slice2(h1_x), self.slice2(h1_y)
        h3_x, h3_y = self.slice3(h2_x), self.slice3(h2_y)
        
        # Combining L1 loss of feature maps
        loss = nn.functional.l1_loss(h1_x, h1_y) + \
               nn.functional.l1_loss(h2_x, h2_y) + \
               nn.functional.l1_loss(h3_x, h3_y)
        return loss

# %%
# --- Initialize Criteria ---
device = "cuda" if torch.cuda.is_available() else "cpu"
BCE = nn.BCEWithLogitsLoss()
L1_LOSS = nn.L1Loss()
PERCEPTUAL_LOSS = VGGPerceptualLoss().to(device)

# --- Hyperparameters ---
LAMBDA_L1 = 100    
LAMBDA_PERC = 10
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:02<00:00, 239MB/s]

# %%
import torch.optim as optim

# --- 1. Initialization ---
# We keep your learning rate at 2e-4, which is the "Goldilocks" zone for Pix2Pix
opt_gen = optim.Adam(list(gen1.parameters()) + list(gen2.parameters()), lr=2e-4, betas=(0.5, 0.999))
opt_disc = optim.Adam(disc.parameters(), lr=2e-4, betas=(0.5, 0.999))

# Using the modern Scaler syntax you started using
scaler = torch.amp.GradScaler('cuda')

# %%
# --- 2. The Training Function ---
def train_step(sketch, real, gen1, gen2, disc, opt_gen, opt_disc, bce, l1, vgg):
    # --- TRAIN DISCRIMINATOR ---
    with torch.amp.autocast('cuda'):
        # Generate the two-stage output
        fake_coarse = gen1(sketch)
        fake_refined = gen2(fake_coarse)
        
        # Real vs Fake scores
        # We use .detach() so we don't calculate gradients for the Generators here
        disc_real = disc(sketch, real)
        disc_fake = disc(sketch, fake_refined.detach())
        
        loss_d_real = bce(disc_real, torch.ones_like(disc_real))
        loss_d_fake = bce(disc_fake, torch.zeros_like(disc_fake))
        loss_d = (loss_d_real + loss_d_fake) / 2

    opt_disc.zero_grad()
    scaler.scale(loss_d).backward()
    scaler.step(opt_disc)
    scaler.update()

    # --- TRAIN GENERATORS ---
    with torch.amp.autocast('cuda'):
        # 1. Adversarial Loss (Fool the critic)
        disc_fake = disc(sketch, fake_refined)
        loss_adv = bce(disc_fake, torch.ones_like(disc_fake))
        
        # 2. Pixel Loss (Structural Accuracy)
        # We calculate L1 for BOTH stages to keep Stage 1 grounded
        loss_l1_coarse = l1(fake_coarse, real) * 10 
        loss_l1_refined = l1(fake_refined, real) * 100
        
        # 3. Perceptual Loss (Texture/Realism)
        loss_vgg = vgg(fake_refined, real) * 10
        
        # Total Generator Loss
        loss_g = loss_adv + loss_l1_refined + loss_l1_coarse + loss_vgg

    opt_gen.zero_grad()
    scaler.scale(loss_g).backward()
    scaler.step(opt_gen)
    scaler.update()
    
    return loss_d, loss_g

# --- 3. Execution Loop ---
NUM_EPOCHS = 10 # 20 is better for seeing the Refiner take effect
for epoch in range(NUM_EPOCHS):
    gen1.train()
    gen2.train()
    disc.train()
    
    for idx, (sketch, real) in enumerate(train_loader):
        sketch, real = sketch.to(device), real.to(device)
        
        ld, lg = train_step(sketch, real, gen1, gen2, disc, opt_gen, opt_disc, BCE, L1_LOSS, PERCEPTUAL_LOSS)
        
        if idx % 100 == 0:
            print(f"Epoch [{epoch}/{NUM_EPOCHS}] Batch [{idx}/{len(train_loader)}] | Loss D: {ld:.4f} Loss G: {lg:.4f}")

    # --- Periodic Visualization (To monitor progress) ---
    # Optional: You can call your visualize_prediction() function here to see progress every epoch
    
    # Save Checkpoint
    if (epoch + 1) % 5 == 0:
        torch.save(gen1.state_dict(), f"gen1_epoch{epoch+1}.pth")
        torch.save(gen2.state_dict(), f"gen2_epoch{epoch+1}.pth")
        print(f"✅ Saved checkpoints for epoch {epoch+1}")
# Out:
# Epoch [0/10] Batch [0/6229] | Loss D: 0.7093 Loss G: 121.4373
# Epoch [0/10] Batch [100/6229] | Loss D: 0.4392 Loss G: 46.0271
# Epoch [0/10] Batch [200/6229] | Loss D: 0.4075 Loss G: 40.6349
# Epoch [0/10] Batch [300/6229] | Loss D: 0.5041 Loss G: 28.9891
# Epoch [0/10] Batch [400/6229] | Loss D: 0.4033 Loss G: 26.9918
# Epoch [0/10] Batch [500/6229] | Loss D: 0.6129 Loss G: 38.5593
# Epoch [0/10] Batch [600/6229] | Loss D: 0.3023 Loss G: 30.6654
# Epoch [0/10] Batch [700/6229] | Loss D: 0.5020 Loss G: 22.9325
# Epoch [0/10] Batch [800/6229] | Loss D: 0.4513 Loss G: 28.4480
# Epoch [0/10] Batch [900/6229] | Loss D: 0.6112 Loss G: 31.6251
# Epoch [0/10] Batch [1000/6229] | Loss D: 0.4746 Loss G: 23.3184
# Epoch [0/10] Batch [1100/6229] | Loss D: 0.8226 Loss G: 28.4308
# Epoch [0/10] Batch [1200/6229] | Loss D: 0.3802 Loss G: 40.7391
# Epoch [0/10] Batch [1300/6229] | Loss D: 0.1447 Loss G: 40.4511
# Epoch [0/10] Batch [1400/6229] | Loss D: 0.1857 Loss G: 27.2586
# Epoch [0/10] Batch [1500/6229] | Loss D: 0.1150 Loss G: 48.4609
# Epoch [0/10] Batch [1600/6229] | Loss D: 0.6294 Loss G: 26.8501
# Epoch [0/10] Batch [1700/6229] | Loss D: 0.5431 Loss G: 21.1653
# Epoch [0/10] Batch [1800/6229] | Loss D: 0.7355 Loss G: 23.2556
# Epoch [0/10] Batch [1900/6229] | Loss D: 0.3313 Loss G: 37.5304
# Epoch [0/10] Batch [2000/6229] | Loss D: 0.5733 Loss G: 24.1691
# Epoch [0/10] Batch [2100/6229] | Loss D: 0.5267 Loss G: 29.2834
# Epoch [0/10] Batch [2200/6229] | Loss D: 0.4423 Loss G: 31.4930
# Epoch [0/10] Batch [2300/6229] | Loss D: 0.3499 Loss G: 27.0206
# Epoch [0/10] Batch [2400/6229] | Loss D: 0.8019 Loss G: 38.5099
# Epoch [0/10] Batch [2500/6229] | Loss D: 0.3100 Loss G: 23.0894
# Epoch [0/10] Batch [2600/6229] | Loss D: 0.3595 Loss G: 37.3597
# Epoch [0/10] Batch [2700/6229] | Loss D: 0.4432 Loss G: 24.4585
# Epoch [0/10] Batch [2800/6229] | Loss D: 0.7455 Loss G: 26.3625
# Epoch [0/10] Batch [2900/6229] | Loss D: 0.4508 Loss G: 40.1644
# Epoch [0/10] Batch [3000/6229] | Loss D: 0.3854 Loss G: 36.4694
# Epoch [0/10] Batch [3100/6229] | Loss D: 0.4644 Loss G: 22.9019
# Epoch [0/10] Batch [3200/6229] | Loss D: 0.4483 Loss G: 26.7086
# Epoch [0/10] Batch [3300/6229] | Loss D: 1.9880 Loss G: 33.0402
# Epoch [0/10] Batch [3400/6229] | Loss D: 1.1491 Loss G: 28.3232
# Epoch [0/10] Batch [3500/6229] | Loss D: 0.2215 Loss G: 28.2167
# Epoch [0/10] Batch [3600/6229] | Loss D: 0.3140 Loss G: 27.2132
# Epoch [0/10] Batch [3700/6229] | Loss D: 0.4820 Loss G: 25.1926
# Epoch [0/10] Batch [3800/6229] | Loss D: 0.2328 Loss G: 32.9096
# Epoch [0/10] Batch [3900/6229] | Loss D: 0.1887 Loss G: 34.2575
# Epoch [0/10] Batch [4000/6229] | Loss D: 0.8418 Loss G: 34.4339
# Epoch [0/10] Batch [4100/6229] | Loss D: 0.3597 Loss G: 36.2416
# Epoch [0/10] Batch [4200/6229] | Loss D: 0.3034 Loss G: 35.8590
# Epoch [0/10] Batch [4300/6229] | Loss D: 0.4330 Loss G: 27.7152
# Epoch [0/10] Batch [4400/6229] | Loss D: 0.4153 Loss G: 29.8635
# Epoch [0/10] Batch [4500/6229] | Loss D: 0.5985 Loss G: 20.4793
# Epoch [0/10] Batch [4600/6229] | Loss D: 0.6704 Loss G: 20.0613
# Epoch [0/10] Batch [4700/6229] | Loss D: 0.2950 Loss G: 27.0684
# Epoch [0/10] Batch [4800/6229] | Loss D: 0.2539 Loss G: 23.7797
# Epoch [0/10] Batch [4900/6229] | Loss D: 0.0933 Loss G: 26.7662
# Epoch [0/10] Batch [5000/6229] | Loss D: 0.4176 Loss G: 36.7133
# Epoch [0/10] Batch [5100/6229] | Loss D: 0.2278 Loss G: 28.0987
# Epoch [0/10] Batch [5200/6229] | Loss D: 1.0538 Loss G: 26.3853
# Epoch [0/10] Batch [5300/6229] | Loss D: 0.1086 Loss G: 32.8349
# Epoch [0/10] Batch [5400/6229] | Loss D: 0.4753 Loss G: 32.0807
# Epoch [0/10] Batch [5500/6229] | Loss D: 0.3664 Loss G: 23.6735
# Epoch [0/10] Batch [5600/6229] | Loss D: 0.2692 Loss G: 25.1368
# Epoch [0/10] Batch [5700/6229] | Loss D: 0.1933 Loss G: 35.9746
# Epoch [0/10] Batch [5800/6229] | Loss D: 0.5010 Loss G: 25.0027
# Epoch [0/10] Batch [5900/6229] | Loss D: 0.3443 Loss G: 28.2441
# Epoch [0/10] Batch [6000/6229] | Loss D: 0.2846 Loss G: 38.6508
# Epoch [0/10] Batch [6100/6229] | Loss D: 0.5307 Loss G: 31.1344
# Epoch [0/10] Batch [6200/6229] | Loss D: 0.3257 Loss G: 28.0031
# Epoch [1/10] Batch [0/6229] | Loss D: 0.3267 Loss G: 39.0783
# Epoch [1/10] Batch [100/6229] | Loss D: 0.1583 Loss G: 32.8334
# Epoch [1/10] Batch [200/6229] | Loss D: 0.2287 Loss G: 28.4895
# Epoch [1/10] Batch [300/6229] | Loss D: 0.6042 Loss G: 29.1037
# Epoch [1/10] Batch [400/6229] | Loss D: 0.1215 Loss G: 37.8601
# Epoch [1/10] Batch [500/6229] | Loss D: 0.6354 Loss G: 23.4455
# Epoch [1/10] Batch [600/6229] | Loss D: 0.5715 Loss G: 31.9998
# Epoch [1/10] Batch [700/6229] | Loss D: 0.6186 Loss G: 29.5453
# Epoch [1/10] Batch [800/6229] | Loss D: 0.3915 Loss G: 29.8605
# Epoch [1/10] Batch [900/6229] | Loss D: 0.1505 Loss G: 42.9982
# Epoch [1/10] Batch [1000/6229] | Loss D: 0.5863 Loss G: 29.6812
# Epoch [1/10] Batch [1100/6229] | Loss D: 0.3358 Loss G: 35.0173
# Epoch [1/10] Batch [1200/6229] | Loss D: 0.6515 Loss G: 32.2846
# Epoch [1/10] Batch [1300/6229] | Loss D: 0.4616 Loss G: 29.5295
# Epoch [1/10] Batch [1400/6229] | Loss D: 1.3196 Loss G: 22.2211
# Epoch [1/10] Batch [1500/6229] | Loss D: 0.9225 Loss G: 21.0026
# Epoch [1/10] Batch [1600/6229] | Loss D: 0.4680 Loss G: 38.3170
# Epoch [1/10] Batch [1700/6229] | Loss D: 0.8399 Loss G: 26.6456
# Epoch [1/10] Batch [1800/6229] | Loss D: 0.6179 Loss G: 23.8331
# Epoch [1/10] Batch [1900/6229] | Loss D: 0.5003 Loss G: 27.0567
# Epoch [1/10] Batch [2000/6229] | Loss D: 0.2807 Loss G: 26.5624
# Epoch [1/10] Batch [2100/6229] | Loss D: 0.1355 Loss G: 31.5960
# Epoch [1/10] Batch [2200/6229] | Loss D: 0.6445 Loss G: 29.2537
# Epoch [1/10] Batch [2300/6229] | Loss D: 0.2584 Loss G: 22.8436
# Epoch [1/10] Batch [2400/6229] | Loss D: 0.1792 Loss G: 39.1232
# Epoch [1/10] Batch [2500/6229] | Loss D: 0.1823 Loss G: 40.7933
# Epoch [1/10] Batch [2600/6229] | Loss D: 0.5605 Loss G: 23.7560
# Epoch [1/10] Batch [2700/6229] | Loss D: 0.2232 Loss G: 29.4012
# Epoch [1/10] Batch [2800/6229] | Loss D: 0.3744 Loss G: 25.7017
# Epoch [1/10] Batch [2900/6229] | Loss D: 0.9229 Loss G: 31.0053
# Epoch [1/10] Batch [3000/6229] | Loss D: 1.1269 Loss G: 28.8343
# Epoch [1/10] Batch [3100/6229] | Loss D: 0.3917 Loss G: 29.6674
# Epoch [1/10] Batch [3200/6229] | Loss D: 0.1203 Loss G: 34.8341
# Epoch [1/10] Batch [3300/6229] | Loss D: 0.2514 Loss G: 38.3505
# Epoch [1/10] Batch [3400/6229] | Loss D: 0.2370 Loss G: 35.3272
# Epoch [1/10] Batch [3500/6229] | Loss D: 1.2499 Loss G: 21.7480
# Epoch [1/10] Batch [3600/6229] | Loss D: 0.0949 Loss G: 30.0841
# Epoch [1/10] Batch [3700/6229] | Loss D: 0.7493 Loss G: 33.3688
# Epoch [1/10] Batch [3800/6229] | Loss D: 0.5759 Loss G: 20.9223
# Epoch [1/10] Batch [3900/6229] | Loss D: 0.1008 Loss G: 31.5454
# Epoch [1/10] Batch [4000/6229] | Loss D: 0.2174 Loss G: 23.4432
# Epoch [1/10] Batch [4100/6229] | Loss D: 0.3771 Loss G: 29.4907
# Epoch [1/10] Batch [4200/6229] | Loss D: 0.1346 Loss G: 27.3154
# Epoch [1/10] Batch [4300/6229] | Loss D: 0.3462 Loss G: 24.5222
# Epoch [1/10] Batch [4400/6229] | Loss D: 0.4674 Loss G: 35.8979
# Epoch [1/10] Batch [4500/6229] | Loss D: 1.1284 Loss G: 26.8923
# Epoch [1/10] Batch [4600/6229] | Loss D: 0.5253 Loss G: 27.2805
# Epoch [1/10] Batch [4700/6229] | Loss D: 0.8273 Loss G: 23.2122
# Epoch [1/10] Batch [4800/6229] | Loss D: 0.3997 Loss G: 22.0856
# Epoch [1/10] Batch [4900/6229] | Loss D: 0.5013 Loss G: 26.7033
# Epoch [1/10] Batch [5000/6229] | Loss D: 0.5461 Loss G: 42.8003
# Epoch [1/10] Batch [5100/6229] | Loss D: 0.1645 Loss G: 34.7407
# Epoch [1/10] Batch [5200/6229] | Loss D: 0.3384 Loss G: 25.2754
# Epoch [1/10] Batch [5300/6229] | Loss D: 0.6040 Loss G: 26.7704
# Epoch [1/10] Batch [5400/6229] | Loss D: 0.1606 Loss G: 27.7267
# Epoch [1/10] Batch [5500/6229] | Loss D: 1.1056 Loss G: 23.6509
# Epoch [1/10] Batch [5600/6229] | Loss D: 0.6724 Loss G: 31.4095
# Epoch [1/10] Batch [5700/6229] | Loss D: 0.2383 Loss G: 28.5818
# Epoch [1/10] Batch [5800/6229] | Loss D: 1.1938 Loss G: 30.2293
# Epoch [1/10] Batch [5900/6229] | Loss D: 0.2987 Loss G: 31.9949
# Epoch [1/10] Batch [6000/6229] | Loss D: 0.8121 Loss G: 33.8827
# Epoch [1/10] Batch [6100/6229] | Loss D: 0.5459 Loss G: 28.8045
# Epoch [1/10] Batch [6200/6229] | Loss D: 0.4122 Loss G: 26.9687
# Epoch [2/10] Batch [0/6229] | Loss D: 0.5688 Loss G: 26.3794
# Epoch [2/10] Batch [100/6229] | Loss D: 0.3298 Loss G: 20.8834
# Epoch [2/10] Batch [200/6229] | Loss D: 1.0238 Loss G: 24.7631
# Epoch [2/10] Batch [300/6229] | Loss D: 0.3165 Loss G: 28.1568
# Epoch [2/10] Batch [400/6229] | Loss D: 0.8725 Loss G: 26.2850
# Epoch [2/10] Batch [500/6229] | Loss D: 0.2795 Loss G: 25.5205
# Epoch [2/10] Batch [600/6229] | Loss D: 0.1885 Loss G: 34.7585
# Epoch [2/10] Batch [700/6229] | Loss D: 0.4188 Loss G: 23.9109
# Epoch [2/10] Batch [800/6229] | Loss D: 0.3757 Loss G: 26.6203
# Epoch [2/10] Batch [900/6229] | Loss D: 0.9394 Loss G: 34.4365
# Epoch [2/10] Batch [1000/6229] | Loss D: 0.2657 Loss G: 32.5631
# Epoch [2/10] Batch [1100/6229] | Loss D: 0.3911 Loss G: 35.1263
# Epoch [2/10] Batch [1200/6229] | Loss D: 0.2565 Loss G: 19.7925
# Epoch [2/10] Batch [1300/6229] | Loss D: 0.1434 Loss G: 27.7633
# Epoch [2/10] Batch [1400/6229] | Loss D: 0.6457 Loss G: 30.8972
# Epoch [2/10] Batch [1500/6229] | Loss D: 0.4625 Loss G: 22.6014
# Epoch [2/10] Batch [1600/6229] | Loss D: 0.8486 Loss G: 21.0620
# Epoch [2/10] Batch [1700/6229] | Loss D: 0.3251 Loss G: 28.4424
# Epoch [2/10] Batch [1800/6229] | Loss D: 1.0408 Loss G: 23.9164
# Epoch [2/10] Batch [1900/6229] | Loss D: 0.2816 Loss G: 29.2379
# Epoch [2/10] Batch [2000/6229] | Loss D: 0.3631 Loss G: 27.2962
# Epoch [2/10] Batch [2100/6229] | Loss D: 0.4949 Loss G: 35.8441
# Epoch [2/10] Batch [2200/6229] | Loss D: 0.3651 Loss G: 26.4250
# Epoch [2/10] Batch [2300/6229] | Loss D: 0.3016 Loss G: 24.9715
# Epoch [2/10] Batch [2400/6229] | Loss D: 0.5816 Loss G: 30.1514
# Epoch [2/10] Batch [2500/6229] | Loss D: 0.3051 Loss G: 37.8506
# Epoch [2/10] Batch [2600/6229] | Loss D: 0.3412 Loss G: 43.3250
# Epoch [2/10] Batch [2700/6229] | Loss D: 0.6103 Loss G: 19.0696
# Epoch [2/10] Batch [2800/6229] | Loss D: 0.6203 Loss G: 27.6169
# Epoch [2/10] Batch [2900/6229] | Loss D: 0.4404 Loss G: 26.0214
# Epoch [2/10] Batch [3000/6229] | Loss D: 0.2520 Loss G: 23.2403
# Epoch [2/10] Batch [3100/6229] | Loss D: 0.1772 Loss G: 28.7367
# Epoch [2/10] Batch [3200/6229] | Loss D: 0.6142 Loss G: 38.0473
# Epoch [2/10] Batch [3300/6229] | Loss D: 0.7781 Loss G: 20.4922
# Epoch [2/10] Batch [3400/6229] | Loss D: 1.0015 Loss G: 20.7339
# Epoch [2/10] Batch [3500/6229] | Loss D: 0.4941 Loss G: 30.2376
# Epoch [2/10] Batch [3600/6229] | Loss D: 0.4446 Loss G: 25.8132
# Epoch [2/10] Batch [3700/6229] | Loss D: 0.4457 Loss G: 22.5358
# Epoch [2/10] Batch [3800/6229] | Loss D: 0.6541 Loss G: 21.7775
# Epoch [2/10] Batch [3900/6229] | Loss D: 0.5153 Loss G: 27.9896
# Epoch [2/10] Batch [4000/6229] | Loss D: 0.3705 Loss G: 29.3139
# Epoch [2/10] Batch [4100/6229] | Loss D: 0.2604 Loss G: 23.1652
# Epoch [2/10] Batch [4200/6229] | Loss D: 0.6442 Loss G: 22.9705
# Epoch [2/10] Batch [4300/6229] | Loss D: 0.8242 Loss G: 33.8107
# Epoch [2/10] Batch [4400/6229] | Loss D: 0.3592 Loss G: 24.3347
# Epoch [2/10] Batch [4500/6229] | Loss D: 0.3326 Loss G: 27.2252
# Epoch [2/10] Batch [4600/6229] | Loss D: 0.3206 Loss G: 26.5970
# Epoch [2/10] Batch [4700/6229] | Loss D: 0.3816 Loss G: 24.6116
# Epoch [2/10] Batch [4800/6229] | Loss D: 0.7766 Loss G: 25.2029
# Epoch [2/10] Batch [4900/6229] | Loss D: 0.4216 Loss G: 27.5580
# Epoch [2/10] Batch [5000/6229] | Loss D: 0.8832 Loss G: 25.3295
# Epoch [2/10] Batch [5100/6229] | Loss D: 0.5296 Loss G: 25.9809
# Epoch [2/10] Batch [5200/6229] | Loss D: 0.1689 Loss G: 31.7060
# Epoch [2/10] Batch [5300/6229] | Loss D: 0.5877 Loss G: 33.6590
# Epoch [2/10] Batch [5400/6229] | Loss D: 0.2912 Loss G: 26.1064
# Epoch [2/10] Batch [5500/6229] | Loss D: 0.8425 Loss G: 18.7024
# Epoch [2/10] Batch [5600/6229] | Loss D: 0.2955 Loss G: 34.1513
# Epoch [2/10] Batch [5700/6229] | Loss D: 1.0188 Loss G: 23.9179
# Epoch [2/10] Batch [5800/6229] | Loss D: 0.6539 Loss G: 20.3956
# Epoch [2/10] Batch [5900/6229] | Loss D: 0.2445 Loss G: 32.2314
# Epoch [2/10] Batch [6000/6229] | Loss D: 0.4172 Loss G: 28.8799
# Epoch [2/10] Batch [6100/6229] | Loss D: 0.4258 Loss G: 20.8877
# Epoch [2/10] Batch [6200/6229] | Loss D: 0.6673 Loss G: 30.1045
# Epoch [3/10] Batch [0/6229] | Loss D: 0.2573 Loss G: 22.0747
# Epoch [3/10] Batch [100/6229] | Loss D: 0.3895 Loss G: 24.2995
# Epoch [3/10] Batch [200/6229] | Loss D: 0.4526 Loss G: 28.5757
# Epoch [3/10] Batch [300/6229] | Loss D: 0.6835 Loss G: 24.9245
# Epoch [3/10] Batch [400/6229] | Loss D: 0.5889 Loss G: 22.5569
# Epoch [3/10] Batch [500/6229] | Loss D: 0.7353 Loss G: 34.1311
# Epoch [3/10] Batch [600/6229] | Loss D: 0.4327 Loss G: 21.1684
# Epoch [3/10] Batch [700/6229] | Loss D: 0.8258 Loss G: 24.0834
# Epoch [3/10] Batch [800/6229] | Loss D: 0.2406 Loss G: 29.5069
# Epoch [3/10] Batch [900/6229] | Loss D: 0.3830 Loss G: 26.0129
# Epoch [3/10] Batch [1000/6229] | Loss D: 0.3111 Loss G: 31.7704
# Epoch [3/10] Batch [1100/6229] | Loss D: 0.6453 Loss G: 27.9367
# Epoch [3/10] Batch [1200/6229] | Loss D: 0.1304 Loss G: 25.2118
# Epoch [3/10] Batch [1300/6229] | Loss D: 0.4004 Loss G: 29.9560
# Epoch [3/10] Batch [1400/6229] | Loss D: 0.6088 Loss G: 21.9384
# Epoch [3/10] Batch [1500/6229] | Loss D: 0.4770 Loss G: 19.7711
# Epoch [3/10] Batch [1600/6229] | Loss D: 0.5478 Loss G: 32.9252
# Epoch [3/10] Batch [1700/6229] | Loss D: 0.3791 Loss G: 33.0456
# Epoch [3/10] Batch [1800/6229] | Loss D: 0.1067 Loss G: 34.8386
# Epoch [3/10] Batch [1900/6229] | Loss D: 0.6932 Loss G: 26.4421
# Epoch [3/10] Batch [2000/6229] | Loss D: 0.3939 Loss G: 25.5294
# Epoch [3/10] Batch [2100/6229] | Loss D: 0.7092 Loss G: 30.3647
# Epoch [3/10] Batch [2200/6229] | Loss D: 0.9072 Loss G: 25.7705
# Epoch [3/10] Batch [2300/6229] | Loss D: 0.6733 Loss G: 27.5809
# Epoch [3/10] Batch [2400/6229] | Loss D: 0.8099 Loss G: 17.9933
# Epoch [3/10] Batch [2500/6229] | Loss D: 0.8781 Loss G: 34.6115
# Epoch [3/10] Batch [2600/6229] | Loss D: 0.8158 Loss G: 17.2801
# Epoch [3/10] Batch [2700/6229] | Loss D: 0.3524 Loss G: 29.7106
# Epoch [3/10] Batch [2800/6229] | Loss D: 0.3364 Loss G: 26.2644
# Epoch [3/10] Batch [2900/6229] | Loss D: 0.6246 Loss G: 29.0512
# Epoch [3/10] Batch [3000/6229] | Loss D: 0.2596 Loss G: 31.1894
# Epoch [3/10] Batch [3100/6229] | Loss D: 0.3695 Loss G: 26.3416
# Epoch [3/10] Batch [3200/6229] | Loss D: 0.6495 Loss G: 20.8550
# Epoch [3/10] Batch [3300/6229] | Loss D: 0.6029 Loss G: 27.9093
# Epoch [3/10] Batch [3400/6229] | Loss D: 0.5168 Loss G: 27.4919
# Epoch [3/10] Batch [3500/6229] | Loss D: 0.7500 Loss G: 21.9461
# Epoch [3/10] Batch [3600/6229] | Loss D: 0.1716 Loss G: 24.8075
# Epoch [3/10] Batch [3700/6229] | Loss D: 0.5800 Loss G: 34.6689
# Epoch [3/10] Batch [3800/6229] | Loss D: 0.1234 Loss G: 29.5478
# Epoch [3/10] Batch [3900/6229] | Loss D: 0.2883 Loss G: 31.8490
# Epoch [3/10] Batch [4000/6229] | Loss D: 0.6784 Loss G: 20.1543
# Epoch [3/10] Batch [4100/6229] | Loss D: 0.6450 Loss G: 25.0242
# Epoch [3/10] Batch [4200/6229] | Loss D: 0.7171 Loss G: 32.7680
# Epoch [3/10] Batch [4300/6229] | Loss D: 1.0488 Loss G: 22.3946
# Epoch [3/10] Batch [4400/6229] | Loss D: 0.3865 Loss G: 25.0936
# Epoch [3/10] Batch [4500/6229] | Loss D: 0.7787 Loss G: 22.7425
# Epoch [3/10] Batch [4600/6229] | Loss D: 0.2241 Loss G: 28.6473
# Epoch [3/10] Batch [4700/6229] | Loss D: 0.6923 Loss G: 24.0627
# Epoch [3/10] Batch [4800/6229] | Loss D: 0.5878 Loss G: 29.2238
# Epoch [3/10] Batch [4900/6229] | Loss D: 0.6056 Loss G: 24.3329
# Epoch [3/10] Batch [5000/6229] | Loss D: 0.6743 Loss G: 23.8221
# Epoch [3/10] Batch [5100/6229] | Loss D: 0.4104 Loss G: 33.5091
# Epoch [3/10] Batch [5200/6229] | Loss D: 0.3488 Loss G: 29.0240
# Epoch [3/10] Batch [5300/6229] | Loss D: 0.2306 Loss G: 22.3401
# Epoch [3/10] Batch [5400/6229] | Loss D: 0.6056 Loss G: 22.4632
# Epoch [3/10] Batch [5500/6229] | Loss D: 0.6832 Loss G: 22.8449
# Epoch [3/10] Batch [5600/6229] | Loss D: 0.1546 Loss G: 25.2744
# Epoch [3/10] Batch [5700/6229] | Loss D: 0.3713 Loss G: 29.5994
# Epoch [3/10] Batch [5800/6229] | Loss D: 0.6186 Loss G: 23.4051
# Epoch [3/10] Batch [5900/6229] | Loss D: 0.6582 Loss G: 20.9282
# Epoch [3/10] Batch [6000/6229] | Loss D: 0.4797 Loss G: 24.1312
# Epoch [3/10] Batch [6100/6229] | Loss D: 0.1680 Loss G: 29.2528
# Epoch [3/10] Batch [6200/6229] | Loss D: 0.2015 Loss G: 28.8662
# Epoch [4/10] Batch [0/6229] | Loss D: 0.3222 Loss G: 22.4893
# Epoch [4/10] Batch [100/6229] | Loss D: 0.4008 Loss G: 25.7377
# Epoch [4/10] Batch [200/6229] | Loss D: 0.6082 Loss G: 21.7976
# Epoch [4/10] Batch [300/6229] | Loss D: 0.7242 Loss G: 24.4046
# Epoch [4/10] Batch [400/6229] | Loss D: 0.4533 Loss G: 26.0933
# Epoch [4/10] Batch [500/6229] | Loss D: 0.2333 Loss G: 28.5199
# Epoch [4/10] Batch [600/6229] | Loss D: 0.2683 Loss G: 23.2551
# Epoch [4/10] Batch [700/6229] | Loss D: 0.4465 Loss G: 23.4923
# Epoch [4/10] Batch [800/6229] | Loss D: 0.6471 Loss G: 26.2747
# Epoch [4/10] Batch [900/6229] | Loss D: 0.3807 Loss G: 22.5894
# Epoch [4/10] Batch [1000/6229] | Loss D: 0.1795 Loss G: 27.9388
# Epoch [4/10] Batch [1100/6229] | Loss D: 0.4104 Loss G: 27.3208
# Epoch [4/10] Batch [1200/6229] | Loss D: 0.0975 Loss G: 27.5322
# Epoch [4/10] Batch [1300/6229] | Loss D: 0.2399 Loss G: 20.6819
# Epoch [4/10] Batch [1400/6229] | Loss D: 0.5643 Loss G: 19.4382
# Epoch [4/10] Batch [1500/6229] | Loss D: 0.8742 Loss G: 23.5580
# Epoch [4/10] Batch [1600/6229] | Loss D: 0.3577 Loss G: 23.5882
# Epoch [4/10] Batch [1700/6229] | Loss D: 0.3527 Loss G: 27.9792
# Epoch [4/10] Batch [1800/6229] | Loss D: 0.5398 Loss G: 24.5840
# Epoch [4/10] Batch [1900/6229] | Loss D: 0.5886 Loss G: 29.0879
# Epoch [4/10] Batch [2000/6229] | Loss D: 0.0958 Loss G: 29.4167
# Epoch [4/10] Batch [2100/6229] | Loss D: 0.2747 Loss G: 19.9738
# Epoch [4/10] Batch [2200/6229] | Loss D: 0.1852 Loss G: 27.3323
# Epoch [4/10] Batch [2300/6229] | Loss D: 0.3866 Loss G: 17.5500
# Epoch [4/10] Batch [2400/6229] | Loss D: 0.2404 Loss G: 30.6109
# Epoch [4/10] Batch [2500/6229] | Loss D: 0.6331 Loss G: 26.2784
# Epoch [4/10] Batch [2600/6229] | Loss D: 0.5818 Loss G: 31.1653
# Epoch [4/10] Batch [2700/6229] | Loss D: 0.4146 Loss G: 26.4658
# Epoch [4/10] Batch [2800/6229] | Loss D: 0.5027 Loss G: 23.4238
# Epoch [4/10] Batch [2900/6229] | Loss D: 1.1595 Loss G: 21.4371
# Epoch [4/10] Batch [3000/6229] | Loss D: 0.8576 Loss G: 28.2767
# Epoch [4/10] Batch [3100/6229] | Loss D: 0.1112 Loss G: 27.5277
# Epoch [4/10] Batch [3200/6229] | Loss D: 0.3386 Loss G: 24.8789
# Epoch [4/10] Batch [3300/6229] | Loss D: 0.9140 Loss G: 27.3344
# Epoch [4/10] Batch [3400/6229] | Loss D: 0.2073 Loss G: 26.6299
# Epoch [4/10] Batch [3500/6229] | Loss D: 0.2337 Loss G: 33.4837
# Epoch [4/10] Batch [3600/6229] | Loss D: 0.4573 Loss G: 27.8539
# Epoch [4/10] Batch [3700/6229] | Loss D: 0.3069 Loss G: 32.5592
# Epoch [4/10] Batch [3800/6229] | Loss D: 1.3712 Loss G: 28.4647
# Epoch [4/10] Batch [3900/6229] | Loss D: 0.5500 Loss G: 21.8802
# Epoch [4/10] Batch [4000/6229] | Loss D: 0.2623 Loss G: 28.4620
# Epoch [4/10] Batch [4100/6229] | Loss D: 0.3831 Loss G: 23.3917
# Epoch [4/10] Batch [4200/6229] | Loss D: 0.3105 Loss G: 23.3381
# Epoch [4/10] Batch [4300/6229] | Loss D: 0.6926 Loss G: 20.0887
# Epoch [4/10] Batch [4400/6229] | Loss D: 0.7810 Loss G: 19.8062
# Epoch [4/10] Batch [4500/6229] | Loss D: 0.9818 Loss G: 28.9095
# Epoch [4/10] Batch [4600/6229] | Loss D: 0.3364 Loss G: 30.2872
# Epoch [4/10] Batch [4700/6229] | Loss D: 1.2274 Loss G: 26.4530
# Epoch [4/10] Batch [4800/6229] | Loss D: 0.4929 Loss G: 24.3603
# Epoch [4/10] Batch [4900/6229] | Loss D: 0.1961 Loss G: 26.7387
# Epoch [4/10] Batch [5000/6229] | Loss D: 0.1198 Loss G: 35.8362
# Epoch [4/10] Batch [5100/6229] | Loss D: 0.4717 Loss G: 24.9082
# Epoch [4/10] Batch [5200/6229] | Loss D: 0.2793 Loss G: 32.3557
# Epoch [4/10] Batch [5300/6229] | Loss D: 0.3096 Loss G: 24.6405
# Epoch [4/10] Batch [5400/6229] | Loss D: 0.2782 Loss G: 21.0775
# Epoch [4/10] Batch [5500/6229] | Loss D: 0.3973 Loss G: 24.1845
# Epoch [4/10] Batch [5600/6229] | Loss D: 0.6813 Loss G: 21.1083
# Epoch [4/10] Batch [5700/6229] | Loss D: 0.7345 Loss G: 24.1731
# Epoch [4/10] Batch [5800/6229] | Loss D: 1.2690 Loss G: 20.9835
# Epoch [4/10] Batch [5900/6229] | Loss D: 0.3991 Loss G: 24.1674
# Epoch [4/10] Batch [6000/6229] | Loss D: 0.2189 Loss G: 28.2070
# Epoch [4/10] Batch [6100/6229] | Loss D: 0.6170 Loss G: 21.4996
# Epoch [4/10] Batch [6200/6229] | Loss D: 0.3652 Loss G: 26.7335
# ✅ Saved checkpoints for epoch 5
# Epoch [5/10] Batch [0/6229] | Loss D: 0.2028 Loss G: 25.8310
# Epoch [5/10] Batch [100/6229] | Loss D: 0.7427 Loss G: 23.6321
# Epoch [5/10] Batch [200/6229] | Loss D: 0.4297 Loss G: 18.8142
# Epoch [5/10] Batch [300/6229] | Loss D: 0.7201 Loss G: 28.3040
# Epoch [5/10] Batch [400/6229] | Loss D: 0.5539 Loss G: 25.1026
# Epoch [5/10] Batch [500/6229] | Loss D: 0.1942 Loss G: 20.7198
# Epoch [5/10] Batch [600/6229] | Loss D: 0.0599 Loss G: 27.6169
# Epoch [5/10] Batch [700/6229] | Loss D: 0.2759 Loss G: 26.6572
# Epoch [5/10] Batch [800/6229] | Loss D: 0.5182 Loss G: 27.0735
# Epoch [5/10] Batch [900/6229] | Loss D: 0.1152 Loss G: 29.8535
# Epoch [5/10] Batch [1000/6229] | Loss D: 0.4481 Loss G: 22.8467
# Epoch [5/10] Batch [1100/6229] | Loss D: 0.4483 Loss G: 25.9333
# Epoch [5/10] Batch [1200/6229] | Loss D: 0.3556 Loss G: 22.2402
# Epoch [5/10] Batch [1300/6229] | Loss D: 0.5500 Loss G: 21.5561
# Epoch [5/10] Batch [1400/6229] | Loss D: 0.4063 Loss G: 23.3670
# Epoch [5/10] Batch [1500/6229] | Loss D: 0.2780 Loss G: 20.7448
# Epoch [5/10] Batch [1600/6229] | Loss D: 0.2689 Loss G: 29.6739
# Epoch [5/10] Batch [1700/6229] | Loss D: 0.4467 Loss G: 23.3444
# Epoch [5/10] Batch [1800/6229] | Loss D: 0.6012 Loss G: 27.9007
# Epoch [5/10] Batch [1900/6229] | Loss D: 0.2987 Loss G: 30.3433
# Epoch [5/10] Batch [2000/6229] | Loss D: 0.3542 Loss G: 22.4962
# Epoch [5/10] Batch [2100/6229] | Loss D: 0.1754 Loss G: 23.5840
# Epoch [5/10] Batch [2200/6229] | Loss D: 0.4391 Loss G: 31.9597
# Epoch [5/10] Batch [2300/6229] | Loss D: 0.5028 Loss G: 24.2756
# Epoch [5/10] Batch [2400/6229] | Loss D: 0.3654 Loss G: 24.9836
# Epoch [5/10] Batch [2500/6229] | Loss D: 0.4331 Loss G: 35.7588
# Epoch [5/10] Batch [2600/6229] | Loss D: 0.3587 Loss G: 31.1275
# Epoch [5/10] Batch [2700/6229] | Loss D: 0.2828 Loss G: 36.6626
# Epoch [5/10] Batch [2800/6229] | Loss D: 0.2086 Loss G: 34.4252
# Epoch [5/10] Batch [2900/6229] | Loss D: 0.9271 Loss G: 29.2970
# Epoch [5/10] Batch [3000/6229] | Loss D: 0.7253 Loss G: 29.0376
# Epoch [5/10] Batch [3100/6229] | Loss D: 0.4094 Loss G: 21.3771
# Epoch [5/10] Batch [3200/6229] | Loss D: 0.5779 Loss G: 27.8078
# Epoch [5/10] Batch [3300/6229] | Loss D: 0.7410 Loss G: 20.1594
# Epoch [5/10] Batch [3400/6229] | Loss D: 0.4471 Loss G: 25.1883
# Epoch [5/10] Batch [3500/6229] | Loss D: 0.5928 Loss G: 27.7153
# Epoch [5/10] Batch [3600/6229] | Loss D: 0.4731 Loss G: 26.8441
# Epoch [5/10] Batch [3700/6229] | Loss D: 0.1871 Loss G: 23.5117
# Epoch [5/10] Batch [3800/6229] | Loss D: 0.2840 Loss G: 27.5284
# Epoch [5/10] Batch [3900/6229] | Loss D: 0.2340 Loss G: 31.2673
# Epoch [5/10] Batch [4000/6229] | Loss D: 1.1171 Loss G: 22.8356
# Epoch [5/10] Batch [4100/6229] | Loss D: 0.1145 Loss G: 27.5243
# Epoch [5/10] Batch [4200/6229] | Loss D: 0.2914 Loss G: 26.8749
# Epoch [5/10] Batch [4300/6229] | Loss D: 0.9866 Loss G: 22.4389
# Epoch [5/10] Batch [4400/6229] | Loss D: 0.1624 Loss G: 20.2615
# Epoch [5/10] Batch [4500/6229] | Loss D: 0.3138 Loss G: 29.4976
# Epoch [5/10] Batch [4600/6229] | Loss D: 0.2810 Loss G: 24.6580
# Epoch [5/10] Batch [4700/6229] | Loss D: 0.4555 Loss G: 28.0459
# Epoch [5/10] Batch [4800/6229] | Loss D: 0.5673 Loss G: 20.5856
# Epoch [5/10] Batch [4900/6229] | Loss D: 0.3784 Loss G: 19.7604
# Epoch [5/10] Batch [5000/6229] | Loss D: 1.0372 Loss G: 17.8914
# Epoch [5/10] Batch [5100/6229] | Loss D: 0.1427 Loss G: 22.5362
# Epoch [5/10] Batch [5200/6229] | Loss D: 0.5098 Loss G: 28.3738
# Epoch [5/10] Batch [5300/6229] | Loss D: 0.7053 Loss G: 18.7306
# Epoch [5/10] Batch [5400/6229] | Loss D: 0.4908 Loss G: 27.7904
# Epoch [5/10] Batch [5500/6229] | Loss D: 0.2155 Loss G: 28.5191
# Epoch [5/10] Batch [5600/6229] | Loss D: 0.2644 Loss G: 27.9036
# Epoch [5/10] Batch [5700/6229] | Loss D: 0.9606 Loss G: 20.6967
# Epoch [5/10] Batch [5800/6229] | Loss D: 0.1533 Loss G: 21.7077
# Epoch [5/10] Batch [5900/6229] | Loss D: 0.3726 Loss G: 30.8502
# Epoch [5/10] Batch [6000/6229] | Loss D: 0.5548 Loss G: 24.6474
# Epoch [5/10] Batch [6100/6229] | Loss D: 0.2681 Loss G: 24.9701
# Epoch [5/10] Batch [6200/6229] | Loss D: 0.1847 Loss G: 27.5793
# Epoch [6/10] Batch [0/6229] | Loss D: 0.8398 Loss G: 30.8581
# Epoch [6/10] Batch [100/6229] | Loss D: 0.3252 Loss G: 27.8646
# Epoch [6/10] Batch [200/6229] | Loss D: 0.3618 Loss G: 32.5972
# Epoch [6/10] Batch [300/6229] | Loss D: 0.5510 Loss G: 31.1149
# Epoch [6/10] Batch [400/6229] | Loss D: 0.1283 Loss G: 26.0743
# Epoch [6/10] Batch [500/6229] | Loss D: 0.2226 Loss G: 26.0857
# Epoch [6/10] Batch [600/6229] | Loss D: 0.5614 Loss G: 22.5576
# Epoch [6/10] Batch [700/6229] | Loss D: 0.3211 Loss G: 20.8240
# Epoch [6/10] Batch [800/6229] | Loss D: 0.3074 Loss G: 22.3028
# Epoch [6/10] Batch [900/6229] | Loss D: 0.2436 Loss G: 29.1173
# Epoch [6/10] Batch [1000/6229] | Loss D: 1.1208 Loss G: 28.3866
# Epoch [6/10] Batch [1100/6229] | Loss D: 0.7337 Loss G: 20.9609
# Epoch [6/10] Batch [1200/6229] | Loss D: 0.5134 Loss G: 26.8283
# Epoch [6/10] Batch [1300/6229] | Loss D: 0.2712 Loss G: 33.4325
# Epoch [6/10] Batch [1400/6229] | Loss D: 0.3144 Loss G: 28.5456
# Epoch [6/10] Batch [1500/6229] | Loss D: 0.5559 Loss G: 33.2882
# Epoch [6/10] Batch [1600/6229] | Loss D: 0.6186 Loss G: 29.9005
# Epoch [6/10] Batch [1700/6229] | Loss D: 0.2005 Loss G: 25.0243
# Epoch [6/10] Batch [1800/6229] | Loss D: 0.1170 Loss G: 35.6461
# Epoch [6/10] Batch [1900/6229] | Loss D: 0.7827 Loss G: 18.9285
# Epoch [6/10] Batch [2000/6229] | Loss D: 0.2727 Loss G: 24.9754
# Epoch [6/10] Batch [2100/6229] | Loss D: 0.2886 Loss G: 25.0223
# Epoch [6/10] Batch [2200/6229] | Loss D: 0.7397 Loss G: 21.7336
# Epoch [6/10] Batch [2300/6229] | Loss D: 0.4245 Loss G: 30.8033
# Epoch [6/10] Batch [2400/6229] | Loss D: 0.3897 Loss G: 19.4890
# Epoch [6/10] Batch [2500/6229] | Loss D: 0.5843 Loss G: 20.8317
# Epoch [6/10] Batch [2600/6229] | Loss D: 0.5349 Loss G: 20.8772
# Epoch [6/10] Batch [2700/6229] | Loss D: 0.2041 Loss G: 25.9316
# Epoch [6/10] Batch [2800/6229] | Loss D: 0.2298 Loss G: 23.8972
# Epoch [6/10] Batch [2900/6229] | Loss D: 0.4056 Loss G: 20.0786
# Epoch [6/10] Batch [3000/6229] | Loss D: 0.4795 Loss G: 19.4831
# Epoch [6/10] Batch [3100/6229] | Loss D: 0.4371 Loss G: 25.9937
# Epoch [6/10] Batch [3200/6229] | Loss D: 0.2767 Loss G: 21.5634
# Epoch [6/10] Batch [3300/6229] | Loss D: 0.5424 Loss G: 21.8725
# Epoch [6/10] Batch [3400/6229] | Loss D: 0.2864 Loss G: 30.3754
# Epoch [6/10] Batch [3500/6229] | Loss D: 0.7651 Loss G: 20.6811
# Epoch [6/10] Batch [3600/6229] | Loss D: 0.1431 Loss G: 23.7596
# Epoch [6/10] Batch [3700/6229] | Loss D: 0.2519 Loss G: 32.6835
# Epoch [6/10] Batch [3800/6229] | Loss D: 0.1960 Loss G: 27.4065
# Epoch [6/10] Batch [3900/6229] | Loss D: 0.8453 Loss G: 23.8230
# Epoch [6/10] Batch [4000/6229] | Loss D: 0.3164 Loss G: 23.5299
# Epoch [6/10] Batch [4100/6229] | Loss D: 0.4614 Loss G: 27.4419
# Epoch [6/10] Batch [4200/6229] | Loss D: 0.3683 Loss G: 27.2768
# Epoch [6/10] Batch [4300/6229] | Loss D: 1.0141 Loss G: 26.8659
# Epoch [6/10] Batch [4400/6229] | Loss D: 0.3693 Loss G: 26.5648
# Epoch [6/10] Batch [4500/6229] | Loss D: 0.7205 Loss G: 25.9067
# Epoch [6/10] Batch [4600/6229] | Loss D: 0.6047 Loss G: 20.2481
# Epoch [6/10] Batch [4700/6229] | Loss D: 1.0046 Loss G: 19.4799
# Epoch [6/10] Batch [4800/6229] | Loss D: 0.5081 Loss G: 24.7419
# Epoch [6/10] Batch [4900/6229] | Loss D: 0.1120 Loss G: 28.1111
# Epoch [6/10] Batch [5000/6229] | Loss D: 0.3464 Loss G: 23.2975
# Epoch [6/10] Batch [5100/6229] | Loss D: 0.7446 Loss G: 24.1520
# Epoch [6/10] Batch [5200/6229] | Loss D: 0.6548 Loss G: 23.0956
# Epoch [6/10] Batch [5300/6229] | Loss D: 0.3467 Loss G: 26.5838
# Epoch [6/10] Batch [5400/6229] | Loss D: 0.9227 Loss G: 26.0816
# Epoch [6/10] Batch [5500/6229] | Loss D: 0.1870 Loss G: 32.1567
# Epoch [6/10] Batch [5600/6229] | Loss D: 0.1741 Loss G: 27.8133
# Epoch [6/10] Batch [5700/6229] | Loss D: 0.2081 Loss G: 26.1820
# Epoch [6/10] Batch [5800/6229] | Loss D: 0.5437 Loss G: 31.5082
# Epoch [6/10] Batch [5900/6229] | Loss D: 0.4181 Loss G: 29.4514
# Epoch [6/10] Batch [6000/6229] | Loss D: 0.5212 Loss G: 23.3584
# Epoch [6/10] Batch [6100/6229] | Loss D: 0.1233 Loss G: 26.2253
# Epoch [6/10] Batch [6200/6229] | Loss D: 0.5996 Loss G: 24.5568
# Epoch [7/10] Batch [0/6229] | Loss D: 0.3113 Loss G: 27.5121
# Epoch [7/10] Batch [100/6229] | Loss D: 0.2608 Loss G: 24.3228
# Epoch [7/10] Batch [200/6229] | Loss D: 0.5165 Loss G: 25.2856
# Epoch [7/10] Batch [300/6229] | Loss D: 0.3101 Loss G: 29.5235
# Epoch [7/10] Batch [400/6229] | Loss D: 0.1981 Loss G: 22.5005
# Epoch [7/10] Batch [500/6229] | Loss D: 0.1221 Loss G: 22.9895
# Epoch [7/10] Batch [600/6229] | Loss D: 0.2416 Loss G: 30.4851
# Epoch [7/10] Batch [700/6229] | Loss D: 0.6333 Loss G: 14.4336
# Epoch [7/10] Batch [800/6229] | Loss D: 0.1571 Loss G: 25.9803
# Epoch [7/10] Batch [900/6229] | Loss D: 0.1511 Loss G: 25.9022
# Epoch [7/10] Batch [1000/6229] | Loss D: 0.2054 Loss G: 29.1206
# Epoch [7/10] Batch [1100/6229] | Loss D: 0.6808 Loss G: 34.7310
# Epoch [7/10] Batch [1200/6229] | Loss D: 0.5318 Loss G: 25.7354
# Epoch [7/10] Batch [1300/6229] | Loss D: 0.6013 Loss G: 31.3595
# Epoch [7/10] Batch [1400/6229] | Loss D: 0.3762 Loss G: 30.3969
# Epoch [7/10] Batch [1500/6229] | Loss D: 0.5042 Loss G: 15.9519
# Epoch [7/10] Batch [1600/6229] | Loss D: 0.4693 Loss G: 22.2170
# Epoch [7/10] Batch [1700/6229] | Loss D: 0.1494 Loss G: 32.3031
# Epoch [7/10] Batch [1800/6229] | Loss D: 0.5352 Loss G: 30.3509
# Epoch [7/10] Batch [1900/6229] | Loss D: 0.1475 Loss G: 23.9803
# Epoch [7/10] Batch [2000/6229] | Loss D: 0.3937 Loss G: 24.4899
# Epoch [7/10] Batch [2100/6229] | Loss D: 0.7486 Loss G: 27.7181
# Epoch [7/10] Batch [2200/6229] | Loss D: 0.5716 Loss G: 26.4526
# Epoch [7/10] Batch [2300/6229] | Loss D: 0.2338 Loss G: 26.5096
# Epoch [7/10] Batch [2400/6229] | Loss D: 0.8401 Loss G: 20.7153
# Epoch [7/10] Batch [2500/6229] | Loss D: 0.3954 Loss G: 24.8991
# Epoch [7/10] Batch [2600/6229] | Loss D: 0.0546 Loss G: 30.4771
# Epoch [7/10] Batch [2700/6229] | Loss D: 0.6265 Loss G: 16.7790
# Epoch [7/10] Batch [2800/6229] | Loss D: 0.5677 Loss G: 25.0233
# Epoch [7/10] Batch [2900/6229] | Loss D: 0.5612 Loss G: 38.9632
# Epoch [7/10] Batch [3000/6229] | Loss D: 0.3632 Loss G: 36.8473
# Epoch [7/10] Batch [3100/6229] | Loss D: 0.3994 Loss G: 23.9475
# Epoch [7/10] Batch [3200/6229] | Loss D: 0.7011 Loss G: 17.5209
# Epoch [7/10] Batch [3300/6229] | Loss D: 0.8008 Loss G: 19.8030
# Epoch [7/10] Batch [3400/6229] | Loss D: 1.0641 Loss G: 31.9904
# Epoch [7/10] Batch [3500/6229] | Loss D: 0.3154 Loss G: 26.7561
# Epoch [7/10] Batch [3600/6229] | Loss D: 0.9827 Loss G: 21.0745
# Epoch [7/10] Batch [3700/6229] | Loss D: 1.2812 Loss G: 26.3838
# Epoch [7/10] Batch [3800/6229] | Loss D: 0.3988 Loss G: 25.6694
# Epoch [7/10] Batch [3900/6229] | Loss D: 0.4360 Loss G: 22.6867
# Epoch [7/10] Batch [4000/6229] | Loss D: 0.6952 Loss G: 23.2399
# Epoch [7/10] Batch [4100/6229] | Loss D: 0.5312 Loss G: 23.9531
# Epoch [7/10] Batch [4200/6229] | Loss D: 0.2943 Loss G: 25.2640
# Epoch [7/10] Batch [4300/6229] | Loss D: 0.2669 Loss G: 22.6745
# Epoch [7/10] Batch [4400/6229] | Loss D: 0.9503 Loss G: 18.4850
# Epoch [7/10] Batch [4500/6229] | Loss D: 0.3738 Loss G: 26.4050
# Epoch [7/10] Batch [4600/6229] | Loss D: 0.1110 Loss G: 28.2309
# Epoch [7/10] Batch [4700/6229] | Loss D: 0.4335 Loss G: 26.7326
# Epoch [7/10] Batch [4800/6229] | Loss D: 0.4209 Loss G: 26.2432
# Epoch [7/10] Batch [4900/6229] | Loss D: 0.2482 Loss G: 22.8840
# Epoch [7/10] Batch [5000/6229] | Loss D: 0.5531 Loss G: 28.9376
# Epoch [7/10] Batch [5100/6229] | Loss D: 0.1311 Loss G: 24.3656
# Epoch [7/10] Batch [5200/6229] | Loss D: 0.6628 Loss G: 23.5904
# Epoch [7/10] Batch [5300/6229] | Loss D: 0.3028 Loss G: 29.5490
# Epoch [7/10] Batch [5400/6229] | Loss D: 0.3880 Loss G: 26.4058
# Epoch [7/10] Batch [5500/6229] | Loss D: 0.5575 Loss G: 31.8950
# Epoch [7/10] Batch [5600/6229] | Loss D: 0.1479 Loss G: 27.4802
# Epoch [7/10] Batch [5700/6229] | Loss D: 0.5289 Loss G: 18.6681
# Epoch [7/10] Batch [5800/6229] | Loss D: 0.2224 Loss G: 24.1473
# Epoch [7/10] Batch [5900/6229] | Loss D: 0.2239 Loss G: 26.1242
# Epoch [7/10] Batch [6000/6229] | Loss D: 0.1559 Loss G: 29.6089
# Epoch [7/10] Batch [6100/6229] | Loss D: 0.1984 Loss G: 19.6887
# Epoch [7/10] Batch [6200/6229] | Loss D: 0.2683 Loss G: 27.4554
# Epoch [8/10] Batch [0/6229] | Loss D: 0.8441 Loss G: 24.6066
# Epoch [8/10] Batch [100/6229] | Loss D: 0.1701 Loss G: 24.9879
# Epoch [8/10] Batch [200/6229] | Loss D: 0.3494 Loss G: 20.6633
# Epoch [8/10] Batch [300/6229] | Loss D: 0.1850 Loss G: 21.6995
# Epoch [8/10] Batch [400/6229] | Loss D: 0.2106 Loss G: 32.7141
# Epoch [8/10] Batch [500/6229] | Loss D: 0.0979 Loss G: 29.0222
# Epoch [8/10] Batch [600/6229] | Loss D: 0.7249 Loss G: 21.5050
# Epoch [8/10] Batch [700/6229] | Loss D: 0.2462 Loss G: 27.1763
# Epoch [8/10] Batch [800/6229] | Loss D: 0.3230 Loss G: 25.8060
# Epoch [8/10] Batch [900/6229] | Loss D: 0.1995 Loss G: 25.0345
# Epoch [8/10] Batch [1000/6229] | Loss D: 0.0511 Loss G: 25.4585
# Epoch [8/10] Batch [1100/6229] | Loss D: 0.7364 Loss G: 15.3661
# Epoch [8/10] Batch [1200/6229] | Loss D: 0.4707 Loss G: 23.4340
# Epoch [8/10] Batch [1300/6229] | Loss D: 0.4665 Loss G: 30.5731
# Epoch [8/10] Batch [1400/6229] | Loss D: 0.2763 Loss G: 22.4584
# Epoch [8/10] Batch [1500/6229] | Loss D: 0.2434 Loss G: 23.7703
# Epoch [8/10] Batch [1600/6229] | Loss D: 0.3659 Loss G: 20.8170
# Epoch [8/10] Batch [1700/6229] | Loss D: 0.6086 Loss G: 28.6525
# Epoch [8/10] Batch [1800/6229] | Loss D: 0.3497 Loss G: 19.5004
# Epoch [8/10] Batch [1900/6229] | Loss D: 1.1412 Loss G: 17.9363
# Epoch [8/10] Batch [2000/6229] | Loss D: 0.0768 Loss G: 28.7085
# Epoch [8/10] Batch [2100/6229] | Loss D: 1.2349 Loss G: 17.4151
# Epoch [8/10] Batch [2200/6229] | Loss D: 0.2919 Loss G: 23.4446
# Epoch [8/10] Batch [2300/6229] | Loss D: 0.4827 Loss G: 26.5003
# Epoch [8/10] Batch [2400/6229] | Loss D: 0.6032 Loss G: 17.0681
# Epoch [8/10] Batch [2500/6229] | Loss D: 0.1778 Loss G: 25.1417
# Epoch [8/10] Batch [2600/6229] | Loss D: 0.3712 Loss G: 21.2451
# Epoch [8/10] Batch [2700/6229] | Loss D: 0.5900 Loss G: 26.3667
# Epoch [8/10] Batch [2800/6229] | Loss D: 0.3765 Loss G: 25.3475
# Epoch [8/10] Batch [2900/6229] | Loss D: 0.2513 Loss G: 18.8093
# Epoch [8/10] Batch [3000/6229] | Loss D: 0.4521 Loss G: 18.2887
# Epoch [8/10] Batch [3100/6229] | Loss D: 0.9528 Loss G: 26.5135
# Epoch [8/10] Batch [3200/6229] | Loss D: 0.4892 Loss G: 20.2994
# Epoch [8/10] Batch [3300/6229] | Loss D: 0.3716 Loss G: 20.8809
# Epoch [8/10] Batch [3400/6229] | Loss D: 0.6605 Loss G: 25.6291
# Epoch [8/10] Batch [3500/6229] | Loss D: 0.3635 Loss G: 22.2562
# Epoch [8/10] Batch [3600/6229] | Loss D: 0.2690 Loss G: 20.5234
# Epoch [8/10] Batch [3700/6229] | Loss D: 0.2771 Loss G: 24.1759
# Epoch [8/10] Batch [3800/6229] | Loss D: 0.1986 Loss G: 24.9634
# Epoch [8/10] Batch [3900/6229] | Loss D: 0.0906 Loss G: 27.5278
# Epoch [8/10] Batch [4000/6229] | Loss D: 0.2684 Loss G: 19.1946
# Epoch [8/10] Batch [4100/6229] | Loss D: 0.1946 Loss G: 26.2990
# Epoch [8/10] Batch [4200/6229] | Loss D: 0.4845 Loss G: 24.5501
# Epoch [8/10] Batch [4300/6229] | Loss D: 0.3604 Loss G: 26.0785
# Epoch [8/10] Batch [4400/6229] | Loss D: 0.3567 Loss G: 22.0768
# Epoch [8/10] Batch [4500/6229] | Loss D: 1.2041 Loss G: 24.8463
# Epoch [8/10] Batch [4600/6229] | Loss D: 0.2748 Loss G: 30.5626
# Epoch [8/10] Batch [4700/6229] | Loss D: 0.5207 Loss G: 28.9384
# Epoch [8/10] Batch [4800/6229] | Loss D: 0.2375 Loss G: 19.0284
# Epoch [8/10] Batch [4900/6229] | Loss D: 0.2657 Loss G: 26.0373
# Epoch [8/10] Batch [5000/6229] | Loss D: 0.4051 Loss G: 24.7665
# Epoch [8/10] Batch [5100/6229] | Loss D: 0.1422 Loss G: 24.1410
# Epoch [8/10] Batch [5200/6229] | Loss D: 0.1796 Loss G: 27.3421
# Epoch [8/10] Batch [5300/6229] | Loss D: 0.4730 Loss G: 22.2056
# Epoch [8/10] Batch [5400/6229] | Loss D: 0.3186 Loss G: 22.7556
# Epoch [8/10] Batch [5500/6229] | Loss D: 0.8248 Loss G: 27.3240
# Epoch [8/10] Batch [5600/6229] | Loss D: 1.1149 Loss G: 21.1297
# Epoch [8/10] Batch [5700/6229] | Loss D: 0.3357 Loss G: 20.6925
# Epoch [8/10] Batch [5800/6229] | Loss D: 0.1356 Loss G: 21.8988
# Epoch [8/10] Batch [5900/6229] | Loss D: 0.5164 Loss G: 24.7779
# Epoch [8/10] Batch [6000/6229] | Loss D: 0.3678 Loss G: 26.0425
# Epoch [8/10] Batch [6100/6229] | Loss D: 1.1673 Loss G: 26.2636
# Epoch [8/10] Batch [6200/6229] | Loss D: 0.6878 Loss G: 19.2068
# Epoch [9/10] Batch [0/6229] | Loss D: 0.3654 Loss G: 43.3322
# Epoch [9/10] Batch [100/6229] | Loss D: 0.2265 Loss G: 35.5722
# Epoch [9/10] Batch [200/6229] | Loss D: 0.2202 Loss G: 31.0223
# Epoch [9/10] Batch [300/6229] | Loss D: 0.9979 Loss G: 23.6751
# Epoch [9/10] Batch [400/6229] | Loss D: 0.5127 Loss G: 28.6708
# Epoch [9/10] Batch [500/6229] | Loss D: 0.5571 Loss G: 26.7370
# Epoch [9/10] Batch [600/6229] | Loss D: 0.5333 Loss G: 22.4181
# Epoch [9/10] Batch [700/6229] | Loss D: 0.4485 Loss G: 22.5711
# Epoch [9/10] Batch [800/6229] | Loss D: 0.4136 Loss G: 27.4496
# Epoch [9/10] Batch [900/6229] | Loss D: 0.5133 Loss G: 20.7265
# Epoch [9/10] Batch [1000/6229] | Loss D: 0.3209 Loss G: 25.8956
# Epoch [9/10] Batch [1100/6229] | Loss D: 0.2142 Loss G: 26.8466
# Epoch [9/10] Batch [1200/6229] | Loss D: 0.7771 Loss G: 21.7051
# Epoch [9/10] Batch [1300/6229] | Loss D: 0.6818 Loss G: 27.5527
# Epoch [9/10] Batch [1400/6229] | Loss D: 0.0451 Loss G: 38.2067
# Epoch [9/10] Batch [1500/6229] | Loss D: 0.6106 Loss G: 20.6049
# Epoch [9/10] Batch [1600/6229] | Loss D: 0.3354 Loss G: 31.1151
# Epoch [9/10] Batch [1700/6229] | Loss D: 0.2421 Loss G: 23.2475
# Epoch [9/10] Batch [1800/6229] | Loss D: 0.2680 Loss G: 25.4332
# Epoch [9/10] Batch [1900/6229] | Loss D: 0.2985 Loss G: 22.9469
# Epoch [9/10] Batch [2000/6229] | Loss D: 0.4249 Loss G: 31.2271
# Epoch [9/10] Batch [2100/6229] | Loss D: 1.1429 Loss G: 25.4029
# Epoch [9/10] Batch [2200/6229] | Loss D: 0.4612 Loss G: 26.2269
# Epoch [9/10] Batch [2300/6229] | Loss D: 0.1637 Loss G: 23.0774
# Epoch [9/10] Batch [2400/6229] | Loss D: 1.0081 Loss G: 20.2660
# Epoch [9/10] Batch [2500/6229] | Loss D: 0.1825 Loss G: 24.8880
# Epoch [9/10] Batch [2600/6229] | Loss D: 0.3265 Loss G: 18.5258
# Epoch [9/10] Batch [2700/6229] | Loss D: 0.5249 Loss G: 19.8308
# Epoch [9/10] Batch [2800/6229] | Loss D: 0.6488 Loss G: 20.5484
# Epoch [9/10] Batch [2900/6229] | Loss D: 0.3633 Loss G: 26.2149
# Epoch [9/10] Batch [3000/6229] | Loss D: 0.4332 Loss G: 34.8003
# Epoch [9/10] Batch [3100/6229] | Loss D: 0.4853 Loss G: 21.2644
# Epoch [9/10] Batch [3200/6229] | Loss D: 0.3531 Loss G: 29.2600
# Epoch [9/10] Batch [3300/6229] | Loss D: 0.1466 Loss G: 22.7263
# Epoch [9/10] Batch [3400/6229] | Loss D: 0.1086 Loss G: 24.6924
# Epoch [9/10] Batch [3500/6229] | Loss D: 0.5479 Loss G: 23.1267
# Epoch [9/10] Batch [3600/6229] | Loss D: 0.3890 Loss G: 20.2151
# Epoch [9/10] Batch [3700/6229] | Loss D: 0.5376 Loss G: 20.1083
# Epoch [9/10] Batch [3800/6229] | Loss D: 0.0989 Loss G: 31.4659
# Epoch [9/10] Batch [3900/6229] | Loss D: 0.3447 Loss G: 28.7104
# Epoch [9/10] Batch [4000/6229] | Loss D: 0.4432 Loss G: 32.0430
# Epoch [9/10] Batch [4100/6229] | Loss D: 0.2459 Loss G: 23.7347
# Epoch [9/10] Batch [4200/6229] | Loss D: 0.5831 Loss G: 20.1614
# Epoch [9/10] Batch [4300/6229] | Loss D: 0.7037 Loss G: 31.4379
# Epoch [9/10] Batch [4400/6229] | Loss D: 0.0945 Loss G: 29.7959
# Epoch [9/10] Batch [4500/6229] | Loss D: 0.5013 Loss G: 22.6216
# Epoch [9/10] Batch [4600/6229] | Loss D: 0.3685 Loss G: 30.3200
# Epoch [9/10] Batch [4700/6229] | Loss D: 0.1520 Loss G: 26.5525
# Epoch [9/10] Batch [4800/6229] | Loss D: 0.3658 Loss G: 34.6023
# Epoch [9/10] Batch [4900/6229] | Loss D: 0.3710 Loss G: 22.1487
# Epoch [9/10] Batch [5000/6229] | Loss D: 0.2035 Loss G: 20.7181
# Epoch [9/10] Batch [5100/6229] | Loss D: 0.8310 Loss G: 25.0193
# Epoch [9/10] Batch [5200/6229] | Loss D: 0.3528 Loss G: 19.4308
# Epoch [9/10] Batch [5300/6229] | Loss D: 0.9861 Loss G: 19.0317
# Epoch [9/10] Batch [5400/6229] | Loss D: 0.4860 Loss G: 23.4179
# Epoch [9/10] Batch [5500/6229] | Loss D: 0.5612 Loss G: 23.7391
# Epoch [9/10] Batch [5600/6229] | Loss D: 0.4927 Loss G: 28.5358
# Epoch [9/10] Batch [5700/6229] | Loss D: 0.4162 Loss G: 22.5814
# Epoch [9/10] Batch [5800/6229] | Loss D: 0.5997 Loss G: 17.2200
# Epoch [9/10] Batch [5900/6229] | Loss D: 1.1469 Loss G: 19.8758
# Epoch [9/10] Batch [6000/6229] | Loss D: 0.6486 Loss G: 17.5318
# Epoch [9/10] Batch [6100/6229] | Loss D: 0.6712 Loss G: 21.2799
# Epoch [9/10] Batch [6200/6229] | Loss D: 0.3671 Loss G: 27.4168
# ✅ Saved checkpoints for epoch 10

# %%
import matplotlib.pyplot as plt

def visualize_stacked_results(g1, g2, loader, device, num_samples=4):
    g1.eval()
    g2.eval()
    sketch, real = next(iter(loader))
    sketch, real = sketch.to(device), real.to(device)
    
    with torch.no_grad():
        coarse = g1(sketch)
        refined = g2(coarse)
    
    # Denormalize [-1, 1] -> [0, 1]
    imgs = [sketch, coarse, refined, real]
    imgs = [img * 0.5 + 0.5 for img in imgs]

    titles = ["Input Sketch", "Stage 1 (Coarse)", "Stage 2 (Refined)", "Real Product"]
    
    plt.figure(figsize=(16, num_samples * 4))
    for i in range(num_samples):
        for j in range(4):
            plt.subplot(num_samples, 4, i*4 + j + 1)
            plt.imshow(imgs[j][i].permute(1, 2, 0).cpu().numpy())
            plt.title(titles[j])
            plt.axis("off")
    
    plt.tight_layout()
    plt.show()

# 1. Visualize the pipeline
visualize_stacked_results(gen1, gen2, train_loader, device)

# 2. Save both models
# These will appear in the /kaggle/working/ directory
torch.save(gen1.state_dict(), "stacked_gen1_architect.pth")
torch.save(gen2.state_dict(), "stacked_gen2_polisher.pth")

print("Pipeline visualization complete and both models saved!")
# Out:
# Pipeline visualization complete and both models saved!
